# %%
# !pip install -q wget

# %%
import pandas as pd 

data_path = '/kaggle/input/task-3-coling-25/test.csv'
data_path = '/kaggle/input/task-3-coling-25/train_none.csv'
df = pd.read_csv(data_path)
df

# %%
# Filter for rows where model is 'human'
human_rows = df[df['model'] == 'human'].head(5)

# Filter for rows where model is not 'human'
other_rows = df[df['model'] != 'human'].head(5)

# Combine both DataFrames
result_df = pd.concat([human_rows, other_rows])

# Reset index for better readability (optional)
result_df.reset_index(drop=True, inplace=True)
result_df
# Out:
#                                      id                         adv_source_id  \
# 0  e5e058ce-be2b-459d-af36-32532aaba5ff  e5e058ce-be2b-459d-af36-32532aaba5ff
# 1  f95b107b-d176-4af5-90f7-4d0bb20caf93  f95b107b-d176-4af5-90f7-4d0bb20caf93
# 2  856d8972-9e3d-4544-babc-0fe16f21e04d  856d8972-9e3d-4544-babc-0fe16f21e04d
# 3  fbc8a5ea-90fa-47b8-8fa7-73dd954f1524  fbc8a5ea-90fa-47b8-8fa7-73dd954f1524
# 4  72c41b8d-0069-4886-b734-a4000ffca286  72c41b8d-0069-4886-b734-a4000ffca286
# 5  2bd98bd7-3356-43bf-8c5d-69ef336d0536  2bd98bd7-3356-43bf-8c5d-69ef336d0536
# 6  e8bdc461-3ff2-4d68-8c7b-cdbc086f62b3  e8bdc461-3ff2-4d68-8c7b-cdbc086f62b3
# 7  ee968d29-ce73-4c5d-804d-0a0efec4bea4  ee968d29-ce73-4c5d-804d-0a0efec4bea4
# 8  3d24eb90-f540-490f-81c8-e4a24fd49ad7  3d24eb90-f540-490f-81c8-e4a24fd49ad7
# 9  5f817bbe-4fb4-4011-a1e9-fcf12990f450  5f817bbe-4fb4-4011-a1e9-fcf12990f450
#
#                               source_id       model  decoding  \
# ...

# %%
reduced_val = 1
#reduced_val = 0.00001
# Sample 10% of the DataFrame
df = df.sample(n=int(len(df) * reduced_val), random_state=42)

df
# Out:
#                                           id  \
# 405948  6ea53940-427e-4315-8d93-00782d9b3009
# 165498  30e378ee-fe2a-44f2-a007-f2b19e7521e9
# 126586  8c2cc761-f250-4301-a3e6-c781b8a242cb
# 358729  dae0fc09-cd22-4b4a-ab75-4c575cd14e52
# 127999  307ff426-6a16-493f-8d4c-667a1db14e8e
# ...                                      ...
# 259178  3d6223f4-1ce1-4268-826d-4e7ccbaf23e5
# 365838  7eb153af-63a4-4803-8484-3a9584dccaf5
# 131932  3e8b9568-21b3-4edc-8e32-b773d66a2e03
# 671155  5330aa4c-4d30-4311-939b-8e82707e75ed
# 121958  808ee701-5df7-4edc-a829-4774bc4d0f90
#
#                                                generation
# 405948  \n\nIngredients:\n\n1 tablespoon olive oil\n\n...
# 165498  \n​\n​E​m​p​i​r​e​ ​o​f​ ​t​h​e​ ​S​u​n​ ​i​s​...
# 126586  In 1844, a young boy named William Thomas Smit...
# 358729  1/2 роund udоn nооdlеs (Jараnеsе thісk whеаt-f...
# 127999  ''Skeletons at the Feast' is a novel written b...
# ...                                                   ...
# ...

# %%
import os
from glob import glob

import torch
import wget
from tqdm import tqdm
from transformers import RobertaForSequenceClassification, RobertaTokenizer


class GPT2Detector:

    path_to_weights = os.path.abspath("detectors/gpt2_detector/openai-gpt-2-detector/detector_weights")
    if not os.path.exists(path_to_weights):
        os.makedirs(path_to_weights)
    device = "cuda" if torch.cuda.is_available() else "cpu"

    def __init__(self, model) -> None:
        self.model_name = model
        self._check_weights()
        self._init_model()

    def _check_weights(self):
        """
        Check if the weights for the given model are present in the current directory.
        If not, download them from the repository.
        """
        if self.model_name == "gpt2-base":
            weights_name = "detector-base.pt"
            if not glob(os.path.join(self.path_to_weights, weights_name)):
                print("Downloading weights for GPT2 Base Detector...")
                wget.download(
                    "https://openaipublic.azureedge.net/gpt-2/detector-models/v1/detector-base.pt",
                    out=os.path.join(self.path_to_weights, weights_name),
                )

        elif self.model_name == "gpt2-large":
            weights_name = "detector-large.pt"
            if not glob(os.path.join(self.path_to_weights, weights_name)):
                print("Downloading weights for GPT2 Large Detector...")
                wget.download(
                    "https://openaipublic.azureedge.net/gpt-2/detector-models/v1/detector-large.pt",
                    out=os.path.join(self.path_to_weights, weights_name),
                )

    def _init_model(self):
        model_name = "roberta-large" if self.model_name == "gpt2-large" else "roberta-base"
        self.model = RobertaForSequenceClassification.from_pretrained(model_name)
        self.tokenizer = RobertaTokenizer.from_pretrained(model_name)

        if self.model_name == "gpt2-base":
            weight_name = "detector-base.pt"
        else:
            weight_name = "detector-large.pt"

        checkpoint = os.path.join(self.path_to_weights, weight_name)
        data = torch.load(checkpoint, map_location="cpu")

        self.model.load_state_dict(data["model_state_dict"], strict=False)
        self.model.eval()

    def inference(self, texts: list) -> list:
        predictions = []
        for text in tqdm(texts):
            tokens = self.tokenizer.encode(text)
            tokens = tokens[: self.tokenizer.model_max_length - 2]
            tokens = torch.tensor([self.tokenizer.bos_token_id] + tokens + [self.tokenizer.eos_token_id]).unsqueeze(0)
            mask = torch.ones_like(tokens)

            self.model = self.model.to(self.device)
            with torch.no_grad():
                logits = self.model(tokens.to(self.device), attention_mask=mask.to(self.device))[0]
                probs = logits.softmax(dim=-1)

            fake, real = probs.detach().cpu().flatten().numpy().tolist()
            print('fake ',fake, ' and real ',real)
            predictions.append(fake)
        return predictions

# %%
# !pip install -q --upgrade transformers
# !pip install -q wandb==0.16.6

# %%
# # Initialize Weights & Biases (W&B) in disabled mode.

import wandb
wandb.init(mode="disabled")

# %%
import torch
from tqdm import tqdm
from transformers import AutoModelForSequenceClassification, AutoTokenizer


class detector_model():
    def __init__(self, model):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.tokenizer = AutoTokenizer.from_pretrained(model)
        self.model = AutoModelForSequenceClassification.from_pretrained(model).to(
            self.device
        )

    def inference(self, texts: list) -> list:
        predictions = []
        for text in tqdm(texts):
            inputs = self.tokenizer(text, truncation=True, return_tensors="pt").to(self.device)
            outputs = self.model(**inputs)
            probs = outputs.logits.softmax(dim=-1)
            real, fake = probs.detach().cpu().flatten().numpy().tolist()
            #print('fake ',fake, ' and real ',real)

            predictions.append(fake)
        return predictions

# %%
model_name = '/kaggle/input/eng-ensemble-coling-final/eng_roberta-base-openai-detector'

detector = detector_model(model_name)
detector

# %%
def run_detection_custom(f, df):
    # Make a copy of the IDs of the original dataframe to avoid editing in place
    scores_df = df[["id"]].copy()

    # Run the detector function on the dataset and put output in score column
    scores_df["score"] = f(df["generation"].tolist())

    # Convert scores and ids to dict in 'records' format for seralization
    # e.g. [{'id':'...', 'score':0}, {'id':'...', 'score':1}, ...]
    results = scores_df[["id", "score"]].to_dict(orient="records")

    return results

# %%
print(f"Running detection...")
results = run_detection_custom(detector.inference, df)
# Out:
# Running detection...
# 100%|██████████| 10/10 [00:00<00:00, 59.37it/s]
# fake  0.0006321206456050277  and real  0.999367892742157
# fake  0.0006438132841140032  and real  0.999356210231781
# fake  0.0006601095083169639  and real  0.9993398785591125
# fake  0.0006723389960825443  and real  0.9993276596069336
# fake  0.0006580671179108322  and real  0.9993419051170349
# fake  0.9989945292472839  and real  0.0010055137099698186
# fake  0.9987949132919312  and real  0.0012050621444359422
# fake  0.9989823698997498  and real  0.0010176600189879537
# fake  0.9989516735076904  and real  0.0010483465157449245
# fake  0.9988312125205994  and real  0.001168795395642519

# %%
import os

import torch
import torch.nn.functional as F
from tqdm import tqdm
from transformers import AutoModelForSequenceClassification, AutoTokenizer


class Radar:
    def __init__(self):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.detector = AutoModelForSequenceClassification.from_pretrained(
            "TrustSafeAI/RADAR-Vicuna-7B", cache_dir=os.environ["CACHE_DIR"]
        )
        self.tokenizer = AutoTokenizer.from_pretrained("TrustSafeAI/RADAR-Vicuna-7B")
        self.detector.eval()
        self.detector.to(self.device)

    def inference(self, texts: list) -> list:
        predictions = []
        for text in tqdm(texts):
            with torch.no_grad():
                inputs = self.tokenizer([text], padding=True, truncation=True, max_length=512, return_tensors="pt")
                inputs = {k: v.to(self.device) for k, v in inputs.items()}
                output_probs = F.log_softmax(self.detector(**inputs).logits, -1)[:, 0].exp().tolist()
                print('outputs ', output_probs)
            predictions.append(output_probs[0])
        return predictions

# radar = Radar()

# %%
results
# Out:
# [{'id': '6ea53940-427e-4315-8d93-00782d9b3009', 'score': 0.9989269375801086},
#  {'id': '30e378ee-fe2a-44f2-a007-f2b19e7521e9', 'score': 0.9977691173553467},
#  {'id': '8c2cc761-f250-4301-a3e6-c781b8a242cb', 'score': 0.998943030834198},
#  {'id': 'dae0fc09-cd22-4b4a-ab75-4c575cd14e52', 'score': 0.02071450650691986},
#  {'id': '307ff426-6a16-493f-8d4c-667a1db14e8e', 'score': 0.9958957433700562},
#  {'id': '22c95125-57f7-4034-b992-689b7bf749c2', 'score': 0.9983057975769043}]

# %%
import json
output_path = f'/kaggle/working/pred_file_trained_roberta_base.json'
with open(output_path, "w") as f:
        json.dump(results, f)

# %%
# from raid import run_detection, run_evaluation
print(f"Running evaluation...")

# Evaluate your detector predictions
# evaluation_result = run_evaluation(results, df)
# Out:
# Running evaluation...

# %% [markdown]
# # ensemble merging

# %%
import pandas as pd

# File paths
file_paths = [
    '/kaggle/input/task3-sub1/task3_pred_chatgpt-roberta.json',
    '/kaggle/input/task3-sub1/task3_pred_gpt2-large.json',
    '/kaggle/input/task3-sub1/task3_pred_gpt2-base.json',
    '/kaggle/input/task3-sub1/task3_pred_radar.json'
]

# Read the JSON files into DataFrames
dfs = [pd.read_json(file) for file in file_paths]

# Rename the score columns to distinguish between the files
dfs[0].rename(columns={'score': 'score_roberta'}, inplace=True)
dfs[1].rename(columns={'score': 'score_gpt2_large'}, inplace=True)
dfs[2].rename(columns={'score': 'score_gpt2_base'}, inplace=True)
dfs[3].rename(columns={'score': 'score_radar'}, inplace=True)

# Merge the DataFrames on the 'id' column
merged_df = dfs[0]
for df in dfs[1:]:
    merged_df = merged_df.merge(df, on='id')


merged_df
# Out:
#                                           id  score_roberta  score_gpt2_large  \
# 0       6ea53940-427e-4315-8d93-00782d9b3009       0.892298          0.990754
# 1       30e378ee-fe2a-44f2-a007-f2b19e7521e9       0.000260          0.955997
# 2       8c2cc761-f250-4301-a3e6-c781b8a242cb       0.999180          0.999440
# 3       dae0fc09-cd22-4b4a-ab75-4c575cd14e52       0.000307          0.270655
# 4       307ff426-6a16-493f-8d4c-667a1db14e8e       0.966942          0.924664
# ...                                      ...            ...               ...
# 671995  3d6223f4-1ce1-4268-826d-4e7ccbaf23e5       0.016321          0.749589
# 671996  7eb153af-63a4-4803-8484-3a9584dccaf5       0.992439          0.909429
# 671997  3e8b9568-21b3-4edc-8e32-b773d66a2e03       0.998721          0.607421
# 671998  5330aa4c-4d30-4311-939b-8e82707e75ed       0.000267          0.900399
# 671999  808ee701-5df7-4edc-a829-4774bc4d0f90       0.244828          0.020988
#
# ...

# %%
# Define the weights for each model (adjust as needed)
weights = {
    'score_roberta': 0.25,
    'score_gpt2_large': 0.25,
    'score_gpt2_base': 0.40,
    'score_radar': 0.60
}

# Calculate the weighted average of the scores
merged_df['weighted_avg_score'] = (
    merged_df['score_roberta'] * weights['score_roberta'] +
    merged_df['score_gpt2_large'] * weights['score_gpt2_large'] +
    merged_df['score_gpt2_base'] * weights['score_gpt2_base'] +
    merged_df['score_radar'] * weights['score_radar']
)

# Display the final DataFrame with weighted average scores
merged_df[['id', 'weighted_avg_score']]
# Out:
#                                           id  weighted_avg_score
# 0       6ea53940-427e-4315-8d93-00782d9b3009            0.966340
# 1       30e378ee-fe2a-44f2-a007-f2b19e7521e9            1.124102
# 2       8c2cc761-f250-4301-a3e6-c781b8a242cb            1.217441
# 3       dae0fc09-cd22-4b4a-ab75-4c575cd14e52            0.439771
# 4       307ff426-6a16-493f-8d4c-667a1db14e8e            0.987192
# ...                                      ...                 ...
# 671995  3d6223f4-1ce1-4268-826d-4e7ccbaf23e5            1.121840
# 671996  7eb153af-63a4-4803-8484-3a9584dccaf5            0.909934
# 671997  3e8b9568-21b3-4edc-8e32-b773d66a2e03            1.268687
# 671998  5330aa4c-4d30-4311-939b-8e82707e75ed            0.991504
# 671999  808ee701-5df7-4edc-a829-4774bc4d0f90            0.420373
#
# [672000 rows x 2 columns]

# %%
import pandas as pd

# List of file paths (you can add more files here)
file_paths = [
    '/kaggle/input/task3-sub1/task3_pred_chatgpt-roberta.json',
    #'/kaggle/input/task3-sub1/task3_pred_gpt2-large.json',
    '/kaggle/input/task3-sub1/task3_pred_gpt2-base.json',
    '/kaggle/input/task3-sub1/task3_pred_radar.json'
]

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop over the file paths to read them and dynamically rename the score column
for i, file in enumerate(file_paths):
    df = pd.read_json(file)  # Read each JSON file
    df.rename(columns={'score': f'score_{i}'}, inplace=True)  # Rename the score column dynamically
    dfs.append(df)  # Append the DataFrame to the list

# Merge all the DataFrames on 'id' column
merged_df = dfs[0]  # Start with the first DataFrame
for df in dfs[1:]:
    merged_df = merged_df.merge(df, on='id')
    
merged_df['score_2'] = 1 - merged_df['score_2']

# Dynamically create weights (for simplicity, we assume equal weights here)
num_files = len(file_paths)
weights = {f'score_{i}': 1 / num_files for i in range(num_files)}  # Equal weights for all files

weights = {f'score_{0}': 0.25, f'score_{1}':0.30, f'score_{2}':0.45}  # Equal weights for all files

print(weights)

# Calculate the weighted average of the scores
merged_df['weighted_avg_score'] = sum(merged_df[f'score_{i}'] * weights[f'score_{i}'] for i in range(num_files))

# Display the final DataFrame with weighted average scores
final_df = merged_df[['id', 'weighted_avg_score']]
final_df.rename(columns={'weighted_avg_score': 'score'}, inplace=True)
final_df
# Out:
# {'score_0': 0.25, 'score_1': 0.3, 'score_2': 0.45}
# /tmp/ipykernel_31/1459633403.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.rename(columns={'weighted_avg_score': 'score'}, inplace=True)
#                                           id     score
# 0       6ea53940-427e-4315-8d93-00782d9b3009  0.901235
# 1       30e378ee-fe2a-44f2-a007-f2b19e7521e9  0.386178
# 2       8c2cc761-f250-4301-a3e6-c781b8a242cb  0.761312
# 3       dae0fc09-cd22-4b4a-ab75-4c575cd14e52  0.421163
# 4       307ff426-6a16-493f-8d4c-667a1db14e8e  0.905905
# ...                                      ...       ...
# 671995  3d6223f4-1ce1-4268-826d-4e7ccbaf23e5  0.356193
# 671996  7eb153af-63a4-4803-8484-3a9584dccaf5  0.972156
# 671997  3e8b9568-21b3-4edc-8e32-b773d66a2e03  0.649201
# ...

# %%
output_path = '/kaggle/working/predictions.json'
#final_df.to_json(output_path, orient='records', lines=True)

# %%
import json

with open(output_path, "w") as f:
  json.dump(final_df[["id", "score"]].to_dict(orient="records"), f)
